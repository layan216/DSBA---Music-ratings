# %%
# Import the libraries we will be using

import os
import numpy as np
import pandas as pd
import math
import matplotlib.pylab as plt
import seaborn as sns

# %matplotlib inline
sns.set(style='ticks', palette='Set2')

# some custom libraries!
import sys
sys.path.append("..")
from ds_utils.decision_surface import *

# %%
url ="https://raw.githubusercontent.com/layan216/DSBA---Music-ratings/master/popnrock_updated.csv"

music_df = pd.read_csv(url).dropna()

music_df.head()
# Out:
#    artist.hotttnesss     artist.name  bars_confidence  bars_start  \
# 1           0.416173   Terry Callier            0.145     0.96908
# 2           0.579989       Van Halen            0.812     0.34761
# 6           0.537537      The B-52's            0.555     0.45372
# 7           0.374271     Horace Andy            0.636     0.55116
# 8           0.409292  The Field Mice            0.020     0.58770
#
#    beats_confidence  beats_start   duration  end_of_fade_in  familiarity  \
# 1             0.708      0.42073  342.56934           0.063     0.706828
# 2             0.812      0.34761  209.29261           0.000     0.744641
# 6             0.000      0.45372  261.74649           3.489     0.681599
# 7             0.636      0.55116  234.44853           0.374     0.626436
# 8             0.910      0.21538  316.73424           0.165     0.605424
#
#     key   ...    start_of_fade_out  tatums_confidence tatums_start    tempo  \
# 1   6.0   ...              333.154              0.462      0.13836  110.189
# 2   8.0   ...              206.623              0.775      0.14268  140.995
# 6   0.0   ...              250.921              0.386      0.20062  124.086
# 7  10.0   ...              222.546              0.842      0.55116  102.055
# 8   3.0   ...              307.177              0.453      0.21538  162.682
#
#           terms  terms_freq  time_signature  time_signature_confidence  \
# 1     soul jazz    0.985011             3.0                      0.353
# 2   heavy metal    0.999932             1.0                      0.410
# 6    dance rock    1.000000             4.0                      0.366
# 7  roots reggae    1.000000             1.0                      0.000
# 8      twee pop    0.883213             4.0                      0.000
#
#                                title    year
# 1       Do You Finally Need A Friend  1972.0
# 2  Panama (Remastered Album Version)     0.0
# 6                                Wig  1986.0
# 7                    Musical Episode  2005.0
# 8         When Morning Comes To Town  1989.0
#
# [5 rows x 32 columns]
